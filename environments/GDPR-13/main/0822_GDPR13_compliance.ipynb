# %% [markdown]
# ## 필수 패키지 설치

# %%
# !pip -q install transformers accelerate torch openai python-dotenv pandas tqdm requests numpy

# %% [markdown]
# ## 하이퍼파라미터

# %%
# ---------- 사용자 설정 (여기를 바꿔 쓰세요) ----------
THRESHOLD = 0.55     # 코사인 유사도 임계값
TOP_K = 8            # 상위 몇 개의 관련 조항을 정보로 넣을지
EMBED_MODEL = "text-embedding-3-large"

# %% [markdown]
# ## 설정 & 유틸

# %%
import os
import re
import json
import time
import math
import numpy as np
import pandas as pd
import requests
from typing import List, Dict, Any, Tuple

from tqdm import tqdm
from dotenv import load_dotenv

import torch
from transformers import AutoTokenizer, AutoModelForCausalLM


# 로컬 저장 옵션
SAVE_OUTPUT_CSV = True
OUTPUT_CSV_PATH = "gdpr_violation_predictions.csv"

# LLM 모델 (Qwen 권장)
MODEL_ID = "Qwen/Qwen2-7B-Instruct"  # 대안: "google/gemma-7b-it", "meta-llama/Llama-3.1-8B-Instruct"

# 생성 파라미터
GEN_ARGS = dict(
    max_new_tokens=8,
    do_sample=False,
    temperature=0.0,
)

# ---------- 환경 변수 ----------
#load_dotenv()
#OPENAI_API_KEY = os.getenv("OPENAI_API_KEY")
OPENAI_API_KEY = ""
if not OPENAI_API_KEY:
    raise RuntimeError("환경변수 OPENAI_API_KEY가 설정되지 않았습니다. .env 파일을 확인하세요.")

# ---------- OpenAI Embeddings ----------
from openai import OpenAI
openai_client = OpenAI(api_key=OPENAI_API_KEY)


def cosine_sim(a: np.ndarray, b: np.ndarray) -> float:
    denom = (np.linalg.norm(a) * np.linalg.norm(b))
    if denom == 0:
        return 0.0
    return float(np.dot(a, b) / denom)

def get_embedding(text: str, model: str = EMBED_MODEL, max_retries: int = 5) -> List[float]:
    text = (text or "").strip()
    last_err = None
    for attempt in range(1, max_retries + 1):
        try:
            resp = openai_client.embeddings.create(model=model, input=text)
            return resp.data[0].embedding
        except Exception as e:
            last_err = e
            sleep_s = (1.8 ** attempt) + 0.1 * attempt
            print(f"[임베딩 재시도 {attempt}/{max_retries}] {e} → {sleep_s:.1f}s 대기")
            time.sleep(sleep_s)
    raise RuntimeError(f"임베딩 생성 실패: {last_err}")

def extract_first_binary_digit(text: str) -> str:
    """
    모델 출력에서 가장 먼저 등장하는 0 또는 1 한 글자만 추출.
    없으면 '0'으로 보수적 판정.
    """
    m = re.search(r"[01]", text)
    return m.group(0) if m else "0"

# %% [markdown]
# ## 데이터 로드

# %%
# =========================================================
# Clone repo via git + git-lfs, then load target files
# =========================================================
import os, json, subprocess, shlex, tempfile, sys
from pathlib import Path
import pandas as pd

# ---------- 사용자 설정 ----------
# 1) GitHub 토큰: 비공개 리포/LFS 권한이 필요하면 넣으세요. 공개라면 빈 문자열 가능
GITHUB_TOKEN = ""  # 예: "ghp_xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx"

# 2) 읽을 대상들 (URL에서 구조만 추출하여 명시)
REPO_OWNER  = "beefed-up-geek"
REPO_NAME   = "compliance_checking"
REPO_REF    = "main"  # branch or tag or commit
# 이벤트 JSON (LFS 파일)
EVENTIC_REL_PATH = "environments/GDPR-13/eventic_with_embedding.json"
# TSV (원래 raw URL이지만, 리포 경로와 동일하므로 로컬에서 읽음)
TSV_REL_PATH     = "environments/GDPR-13/data/original/sample.tsv"

# ---------- 유틸 ----------
def _run(cmd: str, cwd: str | None = None, check: bool = True) -> subprocess.CompletedProcess:
    """Run shell command, raising with readable message on failure."""
    p = subprocess.run(
        cmd if isinstance(cmd, list) else shlex.split(cmd),
        cwd=cwd,
        stdout=subprocess.PIPE,
        stderr=subprocess.PIPE,
        text=True,
    )
    if check and p.returncode != 0:
        msg = (
            f"[CMD FAIL] {cmd}\n"
            f"[STDOUT]\n{p.stdout}\n"
            f"[STDERR]\n{p.stderr}\n"
        )
        raise RuntimeError(msg)
    return p

def _ensure_git_installed():
    try:
        _run("git --version", check=True)
    except Exception as e:
        raise RuntimeError("git이 필요합니다. 환경에 git을 설치해 주세요.") from e

def _ensure_git_lfs_installed(auto_install: bool = True):
    try:
        _run("git lfs version", check=True)
        return
    except Exception:
        if not auto_install:
            raise RuntimeError("git-lfs가 필요합니다. 설치 후 다시 시도하세요.")
        # 시도: Debian/Ubuntu 계열
        print("[INFO] git-lfs가 없어 설치를 시도합니다 (Debian/Ubuntu 계열).")
        try:
            _run("sudo apt-get update", check=True)
            _run("sudo apt-get install -y git-lfs", check=True)
            _run("git lfs install", check=True)
            print("[INFO] git-lfs 설치 완료.")
            return
        except Exception as e:
            # Colab 등 sudo 없는 환경에서 대안: 패키지 미지원 시 수동 설치가 필요할 수 있음
            print("[WARN] 자동 설치 실패. 환경에 맞게 git-lfs를 수동 설치해야 할 수 있습니다.")
            # 그래도 한 번 더 시도
            try:
                _run("git lfs install", check=True)
                return
            except Exception:
                raise RuntimeError("git-lfs 설치가 필요합니다. 수동 설치 후 다시 실행하세요.") from e

def _build_auth_repo_url(owner: str, repo: str, token: str | None) -> str:
    """
    인증이 필요한 경우 토큰을 URL에 내장해서 https 클론.
    Github는 'x-access-token:<token>' 또는 '<token>' 단독도 동작.
    """
    if token:
        # 토큰이 로그에 찍히지 않도록 주의! print 금지.
        return f"https://x-access-token:{token}@github.com/{owner}/{repo}.git"
    else:
        return f"https://github.com/{owner}/{repo}.git"

def clone_repo_and_read_files(owner: str, repo: str, ref: str, rel_paths: list[str], token: str | None = None) -> dict[str, str]:
    """
    - git lfs install
    - git clone --depth=1 --branch <ref>
    - git lfs pull
    - files read as text
    Returns: {rel_path: file_text}
    """
    _ensure_git_installed()
    _ensure_git_lfs_installed(auto_install=True)

    results: dict[str, str] = {}
    auth_url = _build_auth_repo_url(owner, repo, token)
    # 임시 디렉터리에 클론
    with tempfile.TemporaryDirectory() as tmpdir:
        repo_dir = Path(tmpdir) / "repo"

        # clone
        print("[INFO] Cloning repository...")
        _run(f"git clone --depth=1 --branch {shlex.quote(ref)} {auth_url} repo", cwd=tmpdir, check=True)

        # LFS 활성화(관용적으로 1회)
        try:
            _run("git lfs install", cwd=str(repo_dir), check=False)
        except Exception:
            pass

        # lfs pull (필요 오브젝트 받기)
        print("[INFO] Pulling LFS objects (this may take a while)...")
        # 특정 경로만 당기려면: git lfs pull --include="path1,path2"
        _run("git lfs pull", cwd=str(repo_dir), check=False)

        # 파일 읽기
        for rel in rel_paths:
            target = repo_dir / rel
            if not target.exists():
                # lfs checkout 시도 (일부 환경에서 필요)
                _run("git lfs checkout", cwd=str(repo_dir), check=False)
            if not target.exists():
                raise FileNotFoundError(f"파일을 찾을 수 없습니다: {rel} (ref={ref})")
            # 바이너리일 수도 있으므로 우선 바이너리로 열어보고 디코딩
            data = target.read_bytes()
            try:
                text = data.decode("utf-8")
            except UnicodeDecodeError:
                # UTF-8이 아니면 'replace'로라도 텍스트화
                text = data.decode("utf-8", errors="replace")
            results[rel] = text

        print("[INFO] Clone + LFS + Read OK.")
    return results

# ---------- 실행 ----------
token = (GITHUB_TOKEN or "").strip() or None
files_text = clone_repo_and_read_files(
    REPO_OWNER, REPO_NAME, REPO_REF,
    [EVENTIC_REL_PATH, TSV_REL_PATH],
    token=token
)

# JSON 로드
try:
    eventic_text = files_text[EVENTIC_REL_PATH]
    eventic_data = json.loads(eventic_text)
    print(f"[OK] eventic 항목 수: {len(eventic_data)}")
    print(type(eventic_data[0]), list(eventic_data[0].keys())[:6])
except json.JSONDecodeError as e:
    # 혹시 포인터 문서나 바이너리였을 경우 확인을 돕기 위한 헤더 일부 출력
    print("[ERROR] JSON 파싱 실패. 파일 앞부분 미리보기:")
    print(eventic_text[:400])
    raise

# TSV 로드
tsv_text = files_text[TSV_REL_PATH]
# BOM 제거
if tsv_text.startswith("\ufeff"):
    tsv_text = tsv_text.lstrip("\ufeff")

from io import StringIO
df = pd.read_csv(StringIO(tsv_text), sep="\t", dtype=str).fillna("")
print(df.head())
print(f"TSV 샘플 수: {len(df)}")
# Out:
# [INFO] Cloning repository...
# [INFO] Pulling LFS objects (this may take a while)...
# [INFO] Clone + LFS + Read OK.
# [OK] eventic 항목 수: 14
# <class 'dict'> ['Agent', 'Deontic', 'Action', 'Information', 'Paragraph', 'Condition']
#   label                                           sentence        filename
# 0     0                              Frans Erenstraat 14A   www.idates.com
# 1     0  Support requests via compliance @ as well as e...  www.idates.com
# 2     0  Questions Related to Data Protection and Exerc...  www.idates.com
# 3     4  If you have any questions related to data prot...  www.idates.com
# 4     0      In which cases will we process personal data   www.idates.com
# TSV 샘플 수: 361

# %% [markdown]
# ## Qwen 모델 로드 (GPU가 있다면 자동 할당)

# %%
tokenizer = AutoTokenizer.from_pretrained(MODEL_ID, use_fast=True, trust_remote_code=True)
model = AutoModelForCausalLM.from_pretrained(
    MODEL_ID,
    torch_dtype="auto",
    device_map="auto",
    trust_remote_code=True,
)

# pad 토큰 설정(경고 방지)
if tokenizer.pad_token is None:
    tokenizer.pad_token = tokenizer.eos_token

print("Loaded:", MODEL_ID)
print("Model dtype:", model.dtype)
# Out:
# /usr/local/lib/python3.12/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# Loaded: Qwen/Qwen2-7B-Instruct
# Model dtype: torch.bfloat16

# %% [markdown]
# ## 프롬프트 템플릿

# %%
FEW_SHOT_TEMPLATE = """You are a classifier. Your task is to decide whether a given sentence from a website privacy policy indicates a likely GDPR violation.

Output format:
- Output ONLY one number: 1 or 0.
- 1 = The sentence clearly shows a likely GDPR violation.
- 0 = The sentence is compliant, neutral, or not enough to judge as a violation.

Information about GDPR:
<information>
---

Few-shot Examples:

Example 1
Input: "Owner contact email : -Email-"
Output: 0

Example 2
Input: "Frans Erenstraat 14A"
Output: 0

Example 3
Input: "We will process personal data which you transfer to us actively by your entries"
Output: 0

Example 4
Input: "We sell your personal data to third parties without your consent or any legal basis."
Output: 1

Example 5
Input: "Your consent is assumed unless you uncheck the pre-ticked box."
Output: 1

Example 6
Input: "We keep your personal data forever and do not allow deletion requests."
Output: 1

Example 7
Input: "You cannot object to our direct marketing."
Output: 1

Now classify the following sentence:
{sentence}
"""

def build_information_block(relevant_rows: List[Dict[str, Any]]) -> str:
    """
    paragraph [paragraph] agent deontic action information condition 형식으로
    줄바꿈하여 나열.
    """
    lines = []
    for r in relevant_rows:
        paragraph = r.get("Paragraph", "")
        line = (
            f"paragraph [{paragraph}] "
            f"agent {r.get('Agent','')} "
            f"deontic {r.get('Deontic','')} "
            f"action {r.get('Action','')} "
            f"information {r.get('Information','')} "
            f"condition {r.get('Condition','')}"
        )
        lines.append(line)
    return "\n".join(lines) if lines else "N/A"

# %% [markdown]
# ## Eventic 임베딩 행렬 준비 (코사인 유사도용)

# %%
import numpy as np

def _l2_normalize(mat: np.ndarray, eps: float = 1e-12) -> np.ndarray:
    norms = np.linalg.norm(mat, axis=1, keepdims=True)
    norms = np.maximum(norms, eps)
    return mat / norms

# eventic_data에서 embedding 벡터만 추출
eventic_items = eventic_data  # 앞 셀에서 로드되어 있다고 가정
vecs = []
kept_items = []
for it in eventic_items:
    emb = it.get("embedding")
    if isinstance(emb, list) and len(emb) > 0:
        vecs.append(emb)
        kept_items.append(it)

if not vecs:
    raise RuntimeError("eventic_data에 'embedding' 벡터가 없습니다. eventic_with_embedding.json을 확인하세요.")

E = np.array(vecs, dtype=np.float32)
E = _l2_normalize(E)
print(f"[OK] Eventic 임베딩 행렬: shape={E.shape}, 사용 항목 수={len(kept_items)}")
# Out:
# [OK] Eventic 임베딩 행렬: shape=(14, 3072), 사용 항목 수=14

# %% [markdown]
# ## 임베딩 & 매칭 함수 (Top‑K / THRESHOLD None 처리 로직 포함)

# %%
import time
from typing import List, Dict, Any, Tuple

def get_embedding(text: str, model: str = EMBED_MODEL, max_retries: int = 5) -> List[float]:
    text = (text or "").strip()
    last_err = None
    for attempt in range(1, max_retries + 1):
        try:
            resp = openai_client.embeddings.create(model=model, input=text)
            return resp.data[0].embedding
        except Exception as e:
            last_err = e
            time.sleep((1.6 ** attempt) + 0.1 * attempt)
    raise RuntimeError(f"임베딩 생성 실패: {last_err}")

def search_relevant_clauses(
    query_text: str,
    top_k: int | None = TOP_K,
    threshold: float | None = THRESHOLD
) -> List[Tuple[float, Dict[str, Any]]]:
    """
    반환: [(similarity, eventic_item), ...]
    규칙:
      - top_k is None & threshold is None  -> [] (아무 데이터도 추가하지 않음)
      - top_k is None & threshold is not None -> 임계값 이상 모두 반환 (유사도 내림차순)
      - top_k is not None & threshold is None -> 상위 top_k만 반환 (유사도 내림차순)
      - 둘 다 지정 -> 임계값 이상에서 상위 top_k만 반환
    """
    if top_k is None and threshold is None:
        return []

    q = np.array(get_embedding(query_text), dtype=np.float32)
    q = q / (np.linalg.norm(q) + 1e-12)
    sims = E @ q  # 코사인 유사도

    # 공통: 유사도 높은 순 정렬 인덱스
    order = np.argsort(-sims)

    matches = []
    if top_k is None and threshold is not None:
        # 임계값 이상 모두
        for idx in order:
            s = float(sims[idx])
            if s < threshold:
                break
            matches.append((s, kept_items[idx]))
        return matches

    if top_k is not None and threshold is None:
        # 상위 top_k
        k = max(0, int(top_k))
        for idx in order[:k]:
            matches.append((float(sims[idx]), kept_items[idx]))
        return matches

    # 둘 다 지정된 경우: 임계값 이상 중 상위 top_k
    k = max(0, int(top_k))
    for idx in order:
        s = float(sims[idx])
        if s < threshold:
            break
        matches.append((s, kept_items[idx]))
        if len(matches) >= k:
            break
    return matches

# %% [markdown]
# ## \<information\> 블록 생성

# %%
def build_information_block(items: list[dict]) -> str:
    """
    items: [item_dict, ...]
    """
    if not items:
        return ""
    lines = []
    for r in items:
        lines.append(
            f"paragraph [{r.get('Paragraph','')}] "
            f"agent {r.get('Agent','')} "
            f"deontic {r.get('Deontic','')} "
            f"action {r.get('Action','')} "
            f"information {r.get('Information','')} "
            f"condition {r.get('Condition','')}"
        )
    return "\n".join(lines)

# %% [markdown]
# ## 분류 프롬프트 & Qwen 추론 (이미 로드되어 있으면 재사용)

# %%
import re
import torch

# 이미 tokenizer/model을 로드했다면 재사용
try:
    tokenizer, model
except NameError:
    from transformers import AutoTokenizer, AutoModelForCausalLM
    MODEL_ID = "Qwen/Qwen2-7B-Instruct"
    tokenizer = AutoTokenizer.from_pretrained(MODEL_ID, use_fast=True, trust_remote_code=True)
    model = AutoModelForCausalLM.from_pretrained(
        MODEL_ID,
        torch_dtype="auto",
        device_map="auto",
        trust_remote_code=True,
    )
    if tokenizer.pad_token is None:
        tokenizer.pad_token = tokenizer.eos_token
    print("Loaded:", MODEL_ID, "| dtype:", model.dtype)

GEN_ARGS = dict(max_new_tokens=8, do_sample=False, temperature=0.0)

def _extract_first_binary_digit(text: str) -> str:
    m = re.search(r"[01]", text)
    return m.group(0) if m else "0"

def classify_sentence_with_qwen(sentence: str, information_block: str) -> tuple[str, str]:
    prompt = FEW_SHOT_TEMPLATE.format(sentence=sentence)
    prompt = prompt.replace("<information>", (information_block if information_block else "N/A"))

    try:
        # Qwen 채팅 템플릿
        chat = [{"role": "user", "content": prompt}]
        text = tokenizer.apply_chat_template(chat, tokenize=False, add_generation_prompt=True)
    except Exception:
        text = prompt

    inputs = tokenizer(text, return_tensors="pt").to(model.device)
    with torch.no_grad():
        out = model.generate(**inputs, **GEN_ARGS)
    gen = tokenizer.decode(out[0][inputs.input_ids.shape[1]:], skip_special_tokens=True)
    return _extract_first_binary_digit(gen), gen

# %% [markdown]
# ## 하나만 처리해보기

# %%
# ===============================================
# 단일 샘플 처리 (LLM 원출력 확인용)
# ===============================================
# 예시: 첫 번째 데이터
sample_row = df.iloc[0]
sample_sentence = str(sample_row["sentence"])
print("샘플 문장:", sample_sentence)

# 관련 조항 검색 (THRESHOLD/TOP_K 설정 반영)
sample_matches = search_relevant_clauses(sample_sentence, top_k=TOP_K, threshold=THRESHOLD)
sample_info_block = build_information_block(sample_matches)

print("\n--- 관련 조항 (information block) ---")
print(sample_info_block if sample_info_block else "(첨부 없음)")

# Qwen 분류 실행
pred, raw = classify_sentence_with_qwen(sample_sentence, sample_info_block)

print("\n--- 모델 최종 예측 ---")
print("Predicted Label:", pred)

print("\n--- 모델 원출력 (LLM이 추가로 생성한 부분까지) ---")
print(raw)
# Out:
# 샘플 문장: Frans Erenstraat 14A
# The following generation flags are not valid and may be ignored: ['temperature', 'top_p', 'top_k']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# --- 관련 조항 (information block) ---
# (첨부 없음)
#
# --- 모델 최종 예측 ---
# Predicted Label: 0
#
# --- 모델 원출력 (LLM이 추가로 생성한 부분까지) ---
# 0

# %% [markdown]
# ## 전체 분류 루프 + Accuracy / MCC (저장 없음)

# %%
from sklearn.metrics import accuracy_score, matthews_corrcoef
from tqdm import tqdm

# df에는 최소 'sentence'와 'label' 컬럼이 있어야 합니다.
if "sentence" not in df.columns:
    raise ValueError("df에 'sentence' 컬럼이 필요합니다.")
if "label" not in df.columns:
    raise ValueError("df에 'label' 컬럼이 필요합니다.")

pred_labels: list[int] = []
gold_labels: list[int] = []
info_blocks: list[str] = []
raw_outputs: list[str] = []

for _, row in tqdm(df.iterrows(), total=len(df), desc="Classifying"):
    sent = str(row["sentence"])

    # 관련 조항 매칭 (None 로직 포함)
    matches = search_relevant_clauses(sent, top_k=TOP_K, threshold=THRESHOLD)  # [(sim, item), ...]
    only_items = [it for _, it in matches]  # ← item만 추출

    # build_information_block는 Dict 리스트를 기대
    info_block = build_information_block(only_items)
    info_blocks.append(info_block)

    # Qwen 분류
    pred, raw = classify_sentence_with_qwen(sent, info_block)
    pred_labels.append(int(pred))
    raw_outputs.append(raw)

    # 정답 라벨
    gold_labels.append(int(row["label"]))

# 지표
acc = accuracy_score(gold_labels, pred_labels)
mcc = matthews_corrcoef(gold_labels, pred_labels)
print(f"\nAccuracy: {acc:.4f}")
print(f"MCC: {mcc:.4f}")
# Out:
# Classifying:   0%|          | 0/361 [00:00<?, ?it/s]The following generation flags are not valid and may be ignored: ['temperature', 'top_p', 'top_k']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Classifying:   0%|          | 1/361 [00:00<05:09,  1.16it/s]The following generation flags are not valid and may be ignored: ['temperature', 'top_p', 'top_k']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Classifying:   1%|          | 2/361 [00:01<05:17,  1.13it/s]The following generation flags are not valid and may be ignored: ['temperature', 'top_p', 'top_k']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Classifying:   1%|          | 3/361 [00:02<05:12,  1.14it/s]The following generation flags are not valid and may be ignored: ['temperature', 'top_p', 'top_k']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Classifying:   1%|          | 4/361 [00:03<05:05,  1.17it/s]The following generation flags are not valid and may be ignored: ['temperature', 'top_p', 'top_k']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Classifying:   1%|▏         | 5/361 [00:04<04:51,  1.22it/s]The following generation flags are not valid and may be ignored: ['temperature', 'top_p', 'top_k']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Classifying:   2%|▏         | 6/361 [00:04<04:41,  1.26it/s]The following generation flags are not valid and may be ignored: ['temperature', 'top_p', 'top_k']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Classifying:   2%|▏         | 7/361 [00:05<04:50,  1.22it/s]The following generation flags are not valid and may be ignored: ['temperature', 'top_p', 'top_k']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Classifying:   2%|▏         | 8/361 [00:06<05:03,  1.16it/s]The following generation flags are not valid and may be ignored: ['temperature', 'top_p', 'top_k']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Classifying:   2%|▏         | 9/361 [00:07<04:48,  1.22it/s]The following generation flags are not valid and may be ignored: ['temperature', 'top_p', 'top_k']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Classifying:   3%|▎         | 10/361 [00:08<04:40,  1.25it/s]The following generation flags are not valid and may be ignored: ['temperature', 'top_p', 'top_k']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Classifying:   3%|▎         | 11/361 [00:09<04:36,  1.27it/s]The following generation flags are not valid and may be ignored: ['temperature', 'top_p', 'top_k']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Classifying:   3%|▎         | 12/361 [00:10<05:30,  1.06it/s]The following generation flags are not valid and may be ignored: ['temperature', 'top_p', 'top_k']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Classifying:   4%|▎         | 13/361 [00:11<05:15,  1.10it/s]The following generation flags are not valid and may be ignored: ['temperature', 'top_p', 'top_k']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Classifying:   4%|▍         | 14/361 [00:11<04:51,  1.19it/s]The following generation flags are not valid and may be ignored: ['temperature', 'top_p', 'top_k']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Classifying:   4%|▍         | 15/361 [00:12<04:41,  1.23it/s]The following generation flags are not valid and may be ignored: ['temperature', 'top_p', 'top_k']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Classifying:   4%|▍         | 16/361 [00:13<04:43,  1.22it/s]The following generation flags are not valid and may be ignored: ['temperature', 'top_p', 'top_k']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Classifying:   5%|▍         | 17/361 [00:14<04:39,  1.23it/s]The following generation flags are not valid and may be ignored: ['temperature', 'top_p', 'top_k']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Classifying:   5%|▍         | 18/361 [00:15<05:08,  1.11it/s]The following generation flags are not valid and may be ignored: ['temperature', 'top_p', 'top_k']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Classifying:   5%|▌         | 19/361 [00:16<04:52,  1.17it/s]The following generation flags are not valid and may be ignored: ['temperature', 'top_p', 'top_k']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Classifying:   6%|▌         | 20/361 [00:16<04:44,  1.20it/s]The following generation flags are not valid and may be ignored: ['temperature', 'top_p', 'top_k']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Classifying:   6%|▌         | 21/361 [00:17<04:36,  1.23it/s]The following generation flags are not valid and may be ignored: ['temperature', 'top_p', 'top_k']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Classifying:   6%|▌         | 22/361 [00:18<04:42,  1.20it/s]The following generation flags are not valid and may be ignored: ['temperature', 'top_p', 'top_k']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Classifying:   6%|▋         | 23/361 [00:19<04:34,  1.23it/s]The following generation flags are not valid and may be ignored: ['temperature', 'top_p', 'top_k']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Classifying:   7%|▋         | 24/361 [00:20<04:29,  1.25it/s]The following generation flags are not valid and may be ignored: ['temperature', 'top_p', 'top_k']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Classifying:   7%|▋         | 25/361 [00:21<04:49,  1.16it/s]The following generation flags are not valid and may be ignored: ['temperature', 'top_p', 'top_k']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Classifying:   7%|▋         | 26/361 [00:21<04:19,  1.29it/s]The following generation flags are not valid and may be ignored: ['temperature', 'top_p', 'top_k']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Classifying:   7%|▋         | 27/361 [00:22<03:52,  1.44it/s]The following generation flags are not valid and may be ignored: ['temperature', 'top_p', 'top_k']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Classifying:   8%|▊         | 28/361 [00:22<03:52,  1.43it/s]The following generation flags are not valid and may be ignored: ['temperature', 'top_p', 'top_k']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Classifying:   8%|▊         | 29/361 [00:23<03:59,  1.38it/s]The following generation flags are not valid and may be ignored: ['temperature', 'top_p', 'top_k']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Classifying:   8%|▊         | 30/361 [00:24<04:05,  1.35it/s]The following generation flags are not valid and may be ignored: ['temperature', 'top_p', 'top_k']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Classifying:   9%|▊         | 31/361 [00:25<04:11,  1.31it/s]The following generation flags are not valid and may be ignored: ['temperature', 'top_p', 'top_k']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Classifying:   9%|▉         | 32/361 [00:25<04:08,  1.32it/s]The following generation flags are not valid and may be ignored: ['temperature', 'top_p', 'top_k']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Classifying:   9%|▉         | 33/361 [00:26<04:37,  1.18it/s]The following generation flags are not valid and may be ignored: ['temperature', 'top_p', 'top_k']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Classifying:   9%|▉         | 34/361 [00:27<04:32,  1.20it/s]The following generation flags are not valid and may be ignored: ['temperature', 'top_p', 'top_k']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Classifying:  10%|▉         | 35/361 [00:28<04:39,  1.16it/s]The following generation flags are not valid and may be ignored: ['temperature', 'top_p', 'top_k']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Classifying:  10%|▉         | 36/361 [00:29<04:38,  1.17it/s]The following generation flags are not valid and may be ignored: ['temperature', 'top_p', 'top_k']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Classifying:  10%|█         | 37/361 [00:30<04:42,  1.15it/s]The following generation flags are not valid and may be ignored: ['temperature', 'top_p', 'top_k']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Classifying:  11%|█         | 38/361 [00:31<04:24,  1.22it/s]The following generation flags are not valid and may be ignored: ['temperature', 'top_p', 'top_k']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Classifying:  11%|█         | 39/361 [00:32<04:41,  1.15it/s]The following generation flags are not valid and may be ignored: ['temperature', 'top_p', 'top_k']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Classifying:  11%|█         | 40/361 [00:32<04:25,  1.21it/s]The following generation flags are not valid and may be ignored: ['temperature', 'top_p', 'top_k']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Classifying:  11%|█▏        | 41/361 [00:33<04:24,  1.21it/s]The following generation flags are not valid and may be ignored: ['temperature', 'top_p', 'top_k']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Classifying:  12%|█▏        | 42/361 [00:34<04:09,  1.28it/s]The following generation flags are not valid and may be ignored: ['temperature', 'top_p', 'top_k']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Classifying:  12%|█▏        | 43/361 [00:35<04:13,  1.26it/s]The following generation flags are not valid and may be ignored: ['temperature', 'top_p', 'top_k']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Classifying:  12%|█▏        | 44/361 [00:36<04:15,  1.24it/s]The following generation flags are not valid and may be ignored: ['temperature', 'top_p', 'top_k']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Classifying:  12%|█▏        | 45/361 [00:37<04:33,  1.15it/s]The following generation flags are not valid and may be ignored: ['temperature', 'top_p', 'top_k']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Classifying:  13%|█▎        | 46/361 [00:37<04:06,  1.28it/s]The following generation flags are not valid and may be ignored: ['temperature', 'top_p', 'top_k']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Classifying:  13%|█▎        | 47/361 [00:38<04:00,  1.31it/s]The following generation flags are not valid and may be ignored: ['temperature', 'top_p', 'top_k']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Classifying:  13%|█▎        | 48/361 [00:39<03:55,  1.33it/s]The following generation flags are not valid and may be ignored: ['temperature', 'top_p', 'top_k']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Classifying:  14%|█▎        | 49/361 [00:40<04:22,  1.19it/s]The following generation flags are not valid and may be ignored: ['temperature', 'top_p', 'top_k']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Classifying:
  1.30it/s]The following generation flags are not valid and may be ignored: ['temperature', 'top_p', 'top_k']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Classifying:  84%|████████▎ | 302/361 [04:06<00:47,  1.25it/s]The following generation flags are not valid and may be ignored: ['temperature', 'top_p', 'top_k']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Classifying:  84%|████████▍ | 303/361 [04:07<00:47,  1.23it/s]The following generation flags are not valid and may be ignored: ['temperature', 'top_p', 'top_k']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Classifying:  84%|████████▍ | 304/361 [04:08<00:46,  1.23it/s]The following generation flags are not valid and may be ignored: ['temperature', 'top_p', 'top_k']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Classifying:  84%|████████▍ | 305/361 [04:08<00:44,  1.25it/s]The following generation flags are not valid and may be ignored: ['temperature', 'top_p', 'top_k']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Classifying:  85%|████████▍ | 306/361 [04:10<00:48,  1.13it/s]The following generation flags are not valid and may be ignored: ['temperature', 'top_p', 'top_k']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Classifying:  85%|████████▌ | 307/361 [04:10<00:48,  1.12it/s]The following generation flags are not valid and may be ignored: ['temperature', 'top_p', 'top_k']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Classifying:  85%|████████▌ | 308/361 [04:11<00:46,  1.14it/s]The following generation flags are not valid and may be ignored: ['temperature', 'top_p', 'top_k']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Classifying:  86%|████████▌ | 309/361 [04:12<00:43,  1.20it/s]The following generation flags are not valid and may be ignored: ['temperature', 'top_p', 'top_k']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Classifying:  86%|████████▌ | 310/361 [04:13<00:41,  1.24it/s]The following generation flags are not valid and may be ignored: ['temperature', 'top_p', 'top_k']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Classifying:  86%|████████▌ | 311/361 [04:13<00:38,  1.30it/s]The following generation flags are not valid and may be ignored: ['temperature', 'top_p', 'top_k']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Classifying:  86%|████████▋ | 312/361 [04:14<00:37,  1.30it/s]The following generation flags are not valid and may be ignored: ['temperature', 'top_p', 'top_k']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Classifying:  87%|████████▋ | 313/361 [04:15<00:38,  1.24it/s]The following generation flags are not valid and may be ignored: ['temperature', 'top_p', 'top_k']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Classifying:  87%|████████▋ | 314/361 [04:16<00:36,  1.29it/s]The following generation flags are not valid and may be ignored: ['temperature', 'top_p', 'top_k']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Classifying:  87%|████████▋ | 315/361 [04:17<00:36,  1.25it/s]The following generation flags are not valid and may be ignored: ['temperature', 'top_p', 'top_k']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Classifying:  88%|████████▊ | 316/361 [04:17<00:35,  1.28it/s]The following generation flags are not valid and may be ignored: ['temperature', 'top_p', 'top_k']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Classifying:  88%|████████▊ | 317/361 [04:18<00:37,  1.18it/s]The following generation flags are not valid and may be ignored: ['temperature', 'top_p', 'top_k']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Classifying:  88%|████████▊ | 318/361 [04:19<00:31,  1.34it/s]The following generation flags are not valid and may be ignored: ['temperature', 'top_p', 'top_k']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Classifying:  88%|████████▊ | 319/361 [04:20<00:33,  1.25it/s]The following generation flags are not valid and may be ignored: ['temperature', 'top_p', 'top_k']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Classifying:  89%|████████▊ | 320/361 [04:21<00:32,  1.26it/s]The following generation flags are not valid and may be ignored: ['temperature', 'top_p', 'top_k']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Classifying:  89%|████████▉ | 321/361 [04:21<00:31,  1.27it/s]The following generation flags are not valid and may be ignored: ['temperature', 'top_p', 'top_k']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Classifying:  89%|████████▉ | 322/361 [04:22<00:30,  1.27it/s]The following generation flags are not valid and may be ignored: ['temperature', 'top_p', 'top_k']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Classifying:  89%|████████▉ | 323/361 [04:23<00:29,  1.28it/s]The following generation flags are not valid and may be ignored: ['temperature', 'top_p', 'top_k']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Classifying:  90%|████████▉ | 324/361 [04:24<00:29,  1.26it/s]The following generation flags are not valid and may be ignored: ['temperature', 'top_p', 'top_k']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Classifying:  90%|█████████ | 325/361 [04:24<00:27,  1.30it/s]The following generation flags are not valid and may be ignored: ['temperature', 'top_p', 'top_k']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Classifying:  90%|█████████ | 326/361 [04:25<00:26,  1.31it/s]The following generation flags are not valid and may be ignored: ['temperature', 'top_p', 'top_k']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Classifying:  91%|█████████ | 327/361 [04:26<00:26,  1.30it/s]The following generation flags are not valid and may be ignored: ['temperature', 'top_p', 'top_k']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Classifying:  91%|█████████ | 328/361 [04:27<00:26,  1.26it/s]The following generation flags are not valid and may be ignored: ['temperature', 'top_p', 'top_k']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Classifying:  91%|█████████ | 329/361 [04:28<00:24,  1.31it/s]The following generation flags are not valid and may be ignored: ['temperature', 'top_p', 'top_k']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Classifying:  91%|█████████▏| 330/361 [04:28<00:23,  1.33it/s]The following generation flags are not valid and may be ignored: ['temperature', 'top_p', 'top_k']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Classifying:  92%|█████████▏| 331/361 [04:29<00:25,  1.16it/s]The following generation flags are not valid and may be ignored: ['temperature', 'top_p', 'top_k']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Classifying:  92%|█████████▏| 332/361 [04:30<00:24,  1.20it/s]The following generation flags are not valid and may be ignored: ['temperature', 'top_p', 'top_k']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Classifying:  92%|█████████▏| 333/361 [04:31<00:23,  1.17it/s]The following generation flags are not valid and may be ignored: ['temperature', 'top_p', 'top_k']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Classifying:  93%|█████████▎| 334/361 [04:32<00:22,  1.19it/s]The following generation flags are not valid and may be ignored: ['temperature', 'top_p', 'top_k']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Classifying:  93%|█████████▎| 335/361 [04:33<00:21,  1.21it/s]The following generation flags are not valid and may be ignored: ['temperature', 'top_p', 'top_k']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Classifying:  93%|█████████▎| 336/361 [04:33<00:20,  1.22it/s]The following generation flags are not valid and may be ignored: ['temperature', 'top_p', 'top_k']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Classifying:  93%|█████████▎| 337/361 [04:34<00:19,  1.25it/s]The following generation flags are not valid and may be ignored: ['temperature', 'top_p', 'top_k']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Classifying:  94%|█████████▎| 338/361 [04:35<00:18,  1.28it/s]The following generation flags are not valid and may be ignored: ['temperature', 'top_p', 'top_k']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Classifying:  94%|█████████▍| 339/361 [04:36<00:16,  1.29it/s]The following generation flags are not valid and may be ignored: ['temperature', 'top_p', 'top_k']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Classifying:  94%|█████████▍| 340/361 [04:37<00:16,  1.27it/s]The following generation flags are not valid and may be ignored: ['temperature', 'top_p', 'top_k']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Classifying:  94%|█████████▍| 341/361 [04:37<00:16,  1.23it/s]The following generation flags are not valid and may be ignored: ['temperature', 'top_p', 'top_k']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Classifying:  95%|█████████▍| 342/361 [04:38<00:15,  1.22it/s]The following generation flags are not valid and may be ignored: ['temperature', 'top_p', 'top_k']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Classifying:  95%|█████████▌| 343/361 [04:39<00:14,  1.22it/s]The following generation flags are not valid and may be ignored: ['temperature', 'top_p', 'top_k']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Classifying:  95%|█████████▌| 344/361 [04:40<00:13,  1.26it/s]The following generation flags are not valid and may be ignored: ['temperature', 'top_p', 'top_k']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Classifying:  96%|█████████▌| 345/361 [04:41<00:12,  1.27it/s]The following generation flags are not valid and may be ignored: ['temperature', 'top_p', 'top_k']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Classifying:  96%|█████████▌| 346/361 [04:41<00:11,  1.26it/s]The following generation flags are not valid and may be ignored: ['temperature', 'top_p', 'top_k']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Classifying:  96%|█████████▌| 347/361 [04:42<00:10,  1.31it/s]The following generation flags are not valid and may be ignored: ['temperature', 'top_p', 'top_k']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Classifying:  96%|█████████▋| 348/361 [04:43<00:09,  1.33it/s]The following generation flags are not valid and may be ignored: ['temperature', 'top_p', 'top_k']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Classifying:  97%|█████████▋| 349/361 [04:44<00:09,  1.32it/s]The following generation flags are not valid and may be ignored: ['temperature', 'top_p', 'top_k']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Classifying:  97%|█████████▋| 350/361 [04:44<00:08,  1.28it/s]The following generation flags are not valid and may be ignored: ['temperature', 'top_p', 'top_k']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Classifying:  97%|█████████▋| 351/361 [04:45<00:07,  1.31it/s]The following generation flags are not valid and may be ignored: ['temperature', 'top_p', 'top_k']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Classifying:  98%|█████████▊| 352/361 [04:46<00:06,  1.31it/s]The following generation flags are not valid and may be ignored: ['temperature', 'top_p', 'top_k']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Classifying:  98%|█████████▊| 353/361 [04:47<00:06,  1.27it/s]The following generation flags are not valid and may be ignored: ['temperature', 'top_p', 'top_k']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Classifying:  98%|█████████▊| 354/361 [04:47<00:05,  1.33it/s]The following generation flags are not valid and may be ignored: ['temperature', 'top_p', 'top_k']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Classifying:  98%|█████████▊| 355/361 [04:48<00:04,  1.35it/s]The following generation flags are not valid and may be ignored: ['temperature', 'top_p', 'top_k']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Classifying:  99%|█████████▊| 356/361 [04:49<00:03,  1.38it/s]The following generation flags are not valid and may be ignored: ['temperature', 'top_p', 'top_k']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Classifying:  99%|█████████▉| 357/361 [04:50<00:02,  1.37it/s]The following generation flags are not valid and may be ignored: ['temperature', 'top_p', 'top_k']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Classifying:  99%|█████████▉| 358/361 [04:50<00:02,  1.39it/s]The following generation flags are not valid and may be ignored: ['temperature', 'top_p', 'top_k']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Classifying:  99%|█████████▉| 359/361 [04:51<00:01,  1.36it/s]The following generation flags are not valid and may be ignored: ['temperature', 'top_p', 'top_k']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Classifying: 100%|█████████▉| 360/361 [04:52<00:00,  1.37it/s]The following generation flags are not valid and may be ignored: ['temperature', 'top_p', 'top_k']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Classifying: 100%|██████████| 361/361 [04:52<00:00,  1.23it/s]
# Accuracy: 0.8366
# MCC: 0.0117
