# %% [markdown]
# ## Ablation 스위치

# %%
TERM_DEFINITION_ON = True
ENTITY_ON = True
CONCEPT_ON = True
EVENTIC_ON = True
FULL_GRAPH_ON = True # 이게 True면 위의 모든 스위치를 무시하고 모든 내용이 포함됨

# %% [markdown]
# ## 런타임 준비 & 필수 라이브러리 설치 & 허깅페이스 로그인

# %%
# !pip -q install "transformers>=4.43.0" accelerate bitsandbytes "scikit-learn>=1.3.0" pandas tqdm
# !apt-get -qq update
# !apt-get -qq install -y git-lfs
# !git lfs install
# !rm -rf compliance_checking
# !git clone https://github.com/beefed-up-geek/compliance_checking.git
# !pip -q install -U "huggingface_hub[cli]" transformers accelerate

import torch, sys, os, re, json, math, random, pandas as pd
from tqdm import tqdm
from sklearn.metrics import accuracy_score, matthews_corrcoef
from transformers import AutoModelForCausalLM, AutoTokenizer, BitsAndBytesConfig

# !huggingface-cli login
# Out:
# W: Skipping acquire of configured file 'main/source/Sources' as repository 'https://r2u.stat.illinois.edu/ubuntu jammy InRelease' does not seem to provide it (sources.list entry misspelt?)
# Git LFS initialized.
# Cloning into 'compliance_checking'...
# remote: Enumerating objects: 109, done.
# remote: Counting objects: 100% (109/109), done.
# remote: Compressing objects: 100% (93/93), done.
# remote: Total 109 (delta 20), reused 98 (delta 10), pack-reused 0 (from 0)
# Receiving objects: 100% (109/109), 9.36 MiB | 25.35 MiB/s, done.
# Resolving deltas: 100% (20/20), done.
# ⚠️  Warning: 'huggingface-cli login' is deprecated. Use 'hf auth login' instead.
#
#     _|    _|  _|    _|    _|_|_|    _|_|_|  _|_|_|  _|      _|    _|_|_|      _|_|_|_|    _|_|      _|_|_|  _|_|_|_|
#     _|    _|  _|    _|  _|        _|          _|    _|_|    _|  _|            _|        _|    _|  _|        _|
#     _|_|_|_|  _|    _|  _|  _|_|  _|  _|_|    _|    _|  _|  _|  _|  _|_|      _|_|_|    _|_|_|_|  _|        _|_|_|
#     _|    _|  _|    _|  _|    _|  _|    _|    _|    _|    _|_|  _|    _|      _|        _|    _|  _|        _|
#     _|    _|    _|_|      _|_|_|    _|_|_|  _|_|_|  _|      _|    _|_|_|      _|        _|    _|    _|_|_|  _|_|_|_|
#
#     A token is already saved on your machine. Run `hf auth whoami` to get more information or `hf auth logout` if you want to log out.
#     Setting a new token will erase the existing one.
#     To log in, `huggingface_hub` requires a token generated from https://huggingface.co/settings/tokens .
# Enter your token (input will not be visible):
# Add token as git credential? (Y/n) y
# Token is valid (permission: fineGrained).
# The token `250722_HCLT_KACL_2025` has been saved to /root/.cache/huggingface/stored_tokens
# Cannot authenticate through git-credential as no helper is defined on your machine.
# You might have to re-authenticate when pushing to the Hugging Face Hub.
# Run the following command in your terminal in case you want to set the 'store' credential helper as default.
#
# git config --global credential.helper store
#
# Read https://git-scm.com/book/en/v2/Git-Tools-Credential-Storage for more details.
# Token has not been saved to git credential helper.
# Your token has been saved to /root/.cache/huggingface/token
# Login successful.
# The current active token is: `250722_HCLT_KACL_2025`

# %% [markdown]
# ## 모델 로드 (fp16)

# %%
from transformers import AutoModelForCausalLM, AutoTokenizer

# Qwen/Qwen2-7B-Instruct, google/gemma-7b-it, meta-llama/Llama-3.1-8B-Instruct
MODEL_ID = "google/gemma-7b-it"

tokenizer = AutoTokenizer.from_pretrained(MODEL_ID, use_fast=True)
model = AutoModelForCausalLM.from_pretrained(
    MODEL_ID,
    torch_dtype=torch.float16,
    device_map="auto",
    trust_remote_code=True,
)

# pad 토큰 설정(경고 방지)
if tokenizer.pad_token is None:
    tokenizer.pad_token = tokenizer.eos_token

print("Loaded:", MODEL_ID)
print("Model dtype:", model.dtype)
# Out:
# /usr/local/lib/python3.11/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# tokenizer_config.json:   0%|          | 0.00/34.2k [00:00<?, ?B/s]
# tokenizer.model:   0%|          | 0.00/4.24M [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/17.5M [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/636 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/694 [00:00<?, ?B/s]
# model.safetensors.index.json:   0%|          | 0.00/20.9k [00:00<?, ?B/s]
# Fetching 4 files:   0%|          | 0/4 [00:00<?, ?it/s]
# model-00002-of-00004.safetensors:   0%|          | 0.00/4.98G [00:00<?, ?B/s]
# model-00001-of-00004.safetensors:   0%|          | 0.00/5.00G [00:00<?, ?B/s]
# model-00004-of-00004.safetensors:   0%|          | 0.00/2.11G [00:00<?, ?B/s]
# model-00003-of-00004.safetensors:   0%|          | 0.00/4.98G [00:00<?, ?B/s]
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# generation_config.json:   0%|          | 0.00/137 [00:00<?, ?B/s]
# Loaded: google/gemma-7b-it
# Model dtype: torch.float32

# %% [markdown]
# ## 데이터 불러오기

# %%
import json, os

LOCAL_PATH = "compliance_checking/environments/CONTRACT/data/manipulated/contract_norms_fusion_graph.json"
assert os.path.exists(LOCAL_PATH), "파일 경로를 확인하세요."

with open(LOCAL_PATH, "r") as f:
    data = json.load(f)

print(f"총 샘플 수: {len(data)}")
print(json.dumps(data[0], ensure_ascii=False, indent=2)[:1200], "...\n")
# Out:
# 총 샘플 수: 198
# {
#   "contract_id": 466,
#   "norm1": {
#     "norm_id": 82524,
#     "norm_text": "To this end, subject to any confidentiality agreements Solectron may have, Solectron will both inform and provide a commercially reasonable opportunity for acquisition of new and emerging Solectron and industry technology.",
#     "fusion_graph": {
#       "edges": [
#         {
#           "source": "Solectron",
#           "relation": "will",
#           "target": "inform acquisition of new and emerging Solectron and industry technology subject to confidentiality agreements",
#           "source_graph": "eventic"
#         },
#         {
#           "source": "Solectron",
#           "relation": "will",
#           "target": "provide opportunity for acquisition of new and emerging Solectron and industry technology subject to confidentiality agreements",
#           "source_graph": "eventic"
#         },
#         {
#           "source": "Solectron",
#           "relation": "successor",
#           "target": "Flextronics",
#           "source_graph": "entity"
#         },
#         {
#           "source": "Solectron",
#           "relation": "industry",
#           "target": "Electronics Manufacturing Services",
#           "source_graph": "entity"
#       ...

# %% [markdown]
# ## 프롬프트 빌더 & 생성 함수

# %%
SYSTEM_PROMPT = """You are a precise contract-compliance analyst.
Given two norms from the same contract and their fused graphs, decide if they CONFLICT.
Output strictly one digit: 1 if they conflict (mutually unsatisfiable under the same conditions), 0 otherwise.
Do not add any words or punctuation. Only '1' or '0'."""

def filter_edges_by_flags(edges):
    """
    Ablation 스위치에 따라 edge 리스트를 필터링.
    - FULL_GRAPH_ON=True면 그대로 반환 (모든 source_graph 포함).
    - False면 각 스위치(EVENTIC/ENTITY/TERM_DEFINITION/CONCEPT)에 따라 필터링.
    """
    if edges is None:
        return []
    if FULL_GRAPH_ON:
        return edges

    allowed = set()
    if EVENTIC_ON:
        allowed.add("eventic")
    if ENTITY_ON:
        allowed.add("entity")
    if TERM_DEFINITION_ON:
        allowed.add("term_definition")
    if CONCEPT_ON:
        allowed.add("concept")

    out = []
    for e in edges:
        sg = str(e.get("source_graph", "")).strip().lower()
        if sg in allowed:
            out.append(e)
    return out

def edges_to_lines(edges, max_edges=None):
    lines = []
    filt = filter_edges_by_flags(edges)
    use = filt if (max_edges is None) else filt[:max_edges]
    for e in use:
        s = str(e.get("source","")).strip()
        r = str(e.get("relation","")).strip()
        t = str(e.get("target","")).strip()
        lines.append(f"[{s}] [{r}] [{t}]")
    return "\n".join(lines)

def build_user_prompt(sample, max_edges_per_norm=60):
    n1 = sample.get("norm1", {})
    n2 = sample.get("norm2", {})
    n1_id = n1.get("norm_id", "")
    n2_id = n2.get("norm_id", "")
    n1_text = (n1.get("norm_text") or "").strip()
    n2_text = (n2.get("norm_text") or "").strip()
    n1_edges = (n1.get("fusion_graph", {}) or {}).get("edges", [])
    n2_edges = (n2.get("fusion_graph", {}) or {}).get("edges", [])

    # 프롬프트 상단에 어떤 그래프 컴포넌트를 포함했는지 명시
    if FULL_GRAPH_ON:
        components_note = "Included graph components: ALL (full graph: eventic, entity, term_definition, concept)"
    else:
        included = []
        if EVENTIC_ON: included.append("eventic")
        if ENTITY_ON: included.append("entity")
        if TERM_DEFINITION_ON: included.append("term_definition")
        if CONCEPT_ON: included.append("concept")
        if not included:
            components_note = "Included graph components: NONE (edges omitted by ablation)"
        else:
            components_note = "Included graph components: " + ", ".join(included)

    n1_lines = edges_to_lines(n1_edges, max_edges=max_edges_per_norm)
    n2_lines = edges_to_lines(n2_edges, max_edges=max_edges_per_norm)

    user = f"""Decide whether the following two norms conflict.
{components_note}

Norm 1 (id={n1_id}):
{n1_text}

Norm 2 (id={n2_id}):
{n2_text}

Fusion Graph (Norm 1) — one per line: [source] [relation] [target]
{n1_lines}

Fusion Graph (Norm 2) — one per line: [source] [relation] [target]
{n2_lines}

Labeling rule:
- Output 1 if the two norms impose incompatible duties/permissions about the same agent/action under the same conditions such that both cannot be satisfied at once.
- Output 0 otherwise (e.g., different scope/actors/timing, or both can be satisfied).

Answer with ONLY one digit: 1 or 0.
"""
    return user


import re
import torch

@torch.inference_mode()
def predict_label(sample, max_new_tokens=3, temperature=0.0):
    messages = [
        {"role":"user", "content": f"{SYSTEM_PROMPT}/n{build_user_prompt(sample)}"}
    ]
    text = tokenizer.apply_chat_template(messages, tokenize=False, add_generation_prompt=True)
    inputs = tokenizer([text], return_tensors="pt").to(model.device)

    outputs = model.generate(
        **inputs,
        max_new_tokens=max_new_tokens,
        do_sample=False if temperature==0.0 else True,
        temperature=temperature,
        pad_token_id=tokenizer.eos_token_id,
    )
    gen_ids = outputs[0, inputs["input_ids"].shape[1]:]
    out = tokenizer.decode(gen_ids, skip_special_tokens=True).strip()

    # 첫 번째로 보이는 0/1만 사용
    m = re.search(r"[01]", out)
    if m:
        return int(m.group(0)), out
    return 0, out

# %%
# True False
TERM_DEFINITION_ON = True
ENTITY_ON = True
CONCEPT_ON = True
EVENTIC_ON = True
FULL_GRAPH_ON = True # 이게 True면 위의 모든 스위치를 무시하고 모든 내용이 포함됨

# %% [markdown]
# ## 전수 추론 루프 (tqdm 진행바)

# %%
golds, preds, raw_outputs = [], [], []

# fp16에서 메모리 여유가 없다면 60 → 40/30으로 낮추세요.
max_edges_per_norm = 60

from tqdm import tqdm

for sample in tqdm(data, desc="LLM inference"):
    if "norm1" not in sample or "norm2" not in sample or "conflict" not in sample:
        continue

    y_pred, raw = predict_label(sample, max_new_tokens=3, temperature=0.0)
    y_true = int(sample["conflict"])

    preds.append(y_pred)
    golds.append(y_true)
    raw_outputs.append(raw)

print("샘플 수(유효):", len(golds))
# Out:
# LLM inference:   0%|          | 0/198 [00:00<?, ?it/s]The following generation flags are not valid and may be ignored: ['temperature']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# LLM inference:   1%|          | 1/198 [00:01<05:22,  1.64s/it]The following generation flags are not valid and may be ignored: ['temperature']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# LLM inference:   1%|          | 2/198 [00:02<03:19,  1.02s/it]The following generation flags are not valid and may be ignored: ['temperature']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# LLM inference:   2%|▏         | 3/198 [00:03<02:58,  1.09it/s]The following generation flags are not valid and may be ignored: ['temperature']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# LLM inference:   2%|▏         | 4/198 [00:03<02:37,  1.23it/s]The following generation flags are not valid and may be ignored: ['temperature']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# LLM inference:   3%|▎         | 5/198 [00:04<02:50,  1.13it/s]The following generation flags are not valid and may be ignored: ['temperature']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# LLM inference:   3%|▎         | 6/198 [00:05<02:58,  1.08it/s]The following generation flags are not valid and may be ignored: ['temperature']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# LLM inference:   4%|▎         | 7/198 [00:06<02:50,  1.12it/s]The following generation flags are not valid and may be ignored: ['temperature']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# LLM inference:   4%|▍         | 8/198 [00:07<02:45,  1.15it/s]The following generation flags are not valid and may be ignored: ['temperature']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# LLM inference:   5%|▍         | 9/198 [00:08<03:10,  1.01s/it]The following generation flags are not valid and may be ignored: ['temperature']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# LLM inference:   5%|▌         | 10/198 [00:09<03:08,  1.00s/it]The following generation flags are not valid and may be ignored: ['temperature']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# LLM inference:   6%|▌         | 11/198 [00:10<03:07,  1.00s/it]The following generation flags are not valid and may be ignored: ['temperature']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# LLM inference:   6%|▌         | 12/198 [00:11<02:50,  1.09it/s]The following generation flags are not valid and may be ignored: ['temperature']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# LLM inference:   7%|▋         | 13/198 [00:12<02:57,  1.04it/s]The following generation flags are not valid and may be ignored: ['temperature']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# LLM inference:   7%|▋         | 14/198 [00:13<02:43,  1.13it/s]The following generation flags are not valid and may be ignored: ['temperature']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# LLM inference:   8%|▊         | 15/198 [00:13<02:13,  1.37it/s]The following generation flags are not valid and may be ignored: ['temperature']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# LLM inference:   8%|▊         | 16/198 [00:14<02:20,  1.30it/s]The following generation flags are not valid and may be ignored: ['temperature']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# LLM inference:   9%|▊         | 17/198 [00:15<02:22,  1.27it/s]The following generation flags are not valid and may be ignored: ['temperature']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# LLM inference:   9%|▉         | 18/198 [00:16<02:23,  1.25it/s]The following generation flags are not valid and may be ignored: ['temperature']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# LLM inference:  10%|▉         | 19/198 [00:16<02:15,  1.32it/s]The following generation flags are not valid and may be ignored: ['temperature']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# LLM inference:  10%|█         | 20/198 [00:17<02:15,  1.31it/s]The following generation flags are not valid and may be ignored: ['temperature']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# LLM inference:  11%|█         | 21/198 [00:18<02:13,  1.33it/s]The following generation flags are not valid and may be ignored: ['temperature']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# LLM inference:  11%|█         | 22/198 [00:18<01:51,  1.58it/s]The following generation flags are not valid and may be ignored: ['temperature']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# LLM inference:  12%|█▏        | 23/198 [00:19<01:46,  1.64it/s]The following generation flags are not valid and may be ignored: ['temperature']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# LLM inference:  12%|█▏        | 24/198 [00:20<02:06,  1.37it/s]The following generation flags are not valid and may be ignored: ['temperature']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# LLM inference:  13%|█▎        | 25/198 [00:20<01:58,  1.46it/s]The following generation flags are not valid and may be ignored: ['temperature']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# LLM inference:  13%|█▎        | 26/198 [00:21<01:51,  1.55it/s]The following generation flags are not valid and may be ignored: ['temperature']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# LLM inference:  14%|█▎        | 27/198 [00:21<01:44,  1.63it/s]The following generation flags are not valid and may be ignored: ['temperature']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# LLM inference:  14%|█▍        | 28/198 [00:22<02:01,  1.40it/s]The following generation flags are not valid and may be ignored: ['temperature']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# LLM inference:  15%|█▍        | 29/198 [00:23<02:03,  1.37it/s]The following generation flags are not valid and may be ignored: ['temperature']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# LLM inference:  15%|█▌        | 30/198 [00:24<02:19,  1.20it/s]The following generation flags are not valid and may be ignored: ['temperature']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# LLM inference:  16%|█▌        | 31/198 [00:25<02:20,  1.19it/s]The following generation flags are not valid and may be ignored: ['temperature']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# LLM inference:  16%|█▌        | 32/198 [00:26<02:25,  1.14it/s]The following generation flags are not valid and may be ignored: ['temperature']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# LLM inference:  17%|█▋        | 33/198 [00:26<02:04,  1.32it/s]The following generation flags are not valid and may be ignored: ['temperature']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# LLM inference:  17%|█▋        | 34/198 [00:27<01:53,  1.45it/s]The following generation flags are not valid and may be ignored: ['temperature']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# LLM inference:  18%|█▊        | 35/198 [00:27<01:47,  1.52it/s]The following generation flags are not valid and may be ignored: ['temperature']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# LLM inference:  18%|█▊        | 36/198 [00:28<01:50,  1.47it/s]The following generation flags are not valid and may be ignored: ['temperature']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# LLM inference:  19%|█▊        | 37/198 [00:29<01:51,  1.44it/s]The following generation flags are not valid and may be ignored: ['temperature']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# LLM inference:  19%|█▉        | 38/198 [00:30<01:55,  1.38it/s]The following generation flags are not valid and may be ignored: ['temperature']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# LLM inference:  20%|█▉        | 39/198 [00:31<01:57,  1.36it/s]The following generation flags are not valid and may be ignored: ['temperature']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# LLM inference:  20%|██        | 40/198 [00:32<02:08,  1.23it/s]The following generation flags are not valid and may be ignored: ['temperature']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# LLM inference:  21%|██        | 41/198 [00:33<02:17,  1.14it/s]The following generation flags are not valid and may be ignored: ['temperature']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# LLM inference:  21%|██        | 42/198 [00:33<02:20,  1.11it/s]The following generation flags are not valid and may be ignored: ['temperature']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# LLM inference:  22%|██▏       | 43/198 [00:34<01:59,  1.29it/s]The following generation flags are not valid and may be ignored: ['temperature']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# LLM inference:
/s]The following generation flags are not valid and may be ignored: ['temperature']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# LLM inference:  77%|███████▋  | 153/198 [01:49<00:27,  1.66it/s]The following generation flags are not valid and may be ignored: ['temperature']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# LLM inference:  78%|███████▊  | 154/198 [01:50<00:28,  1.56it/s]The following generation flags are not valid and may be ignored: ['temperature']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# LLM inference:  78%|███████▊  | 155/198 [01:50<00:26,  1.62it/s]The following generation flags are not valid and may be ignored: ['temperature']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# LLM inference:  79%|███████▉  | 156/198 [01:51<00:28,  1.47it/s]The following generation flags are not valid and may be ignored: ['temperature']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# LLM inference:  79%|███████▉  | 157/198 [01:52<00:27,  1.48it/s]The following generation flags are not valid and may be ignored: ['temperature']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# LLM inference:  80%|███████▉  | 158/198 [01:52<00:25,  1.58it/s]The following generation flags are not valid and may be ignored: ['temperature']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# LLM inference:  80%|████████  | 159/198 [01:53<00:27,  1.42it/s]The following generation flags are not valid and may be ignored: ['temperature']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# LLM inference:  81%|████████  | 160/198 [01:54<00:29,  1.28it/s]The following generation flags are not valid and may be ignored: ['temperature']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# LLM inference:  81%|████████▏ | 161/198 [01:55<00:27,  1.35it/s]The following generation flags are not valid and may be ignored: ['temperature']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# LLM inference:  82%|████████▏ | 162/198 [01:55<00:25,  1.44it/s]The following generation flags are not valid and may be ignored: ['temperature']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# LLM inference:  82%|████████▏ | 163/198 [01:56<00:24,  1.46it/s]The following generation flags are not valid and may be ignored: ['temperature']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# LLM inference:  83%|████████▎ | 164/198 [01:57<00:26,  1.28it/s]The following generation flags are not valid and may be ignored: ['temperature']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# LLM inference:  83%|████████▎ | 165/198 [01:57<00:22,  1.45it/s]The following generation flags are not valid and may be ignored: ['temperature']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# LLM inference:  84%|████████▍ | 166/198 [01:58<00:18,  1.69it/s]The following generation flags are not valid and may be ignored: ['temperature']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# LLM inference:  84%|████████▍ | 167/198 [01:58<00:17,  1.73it/s]The following generation flags are not valid and may be ignored: ['temperature']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# LLM inference:  85%|████████▍ | 168/198 [01:59<00:16,  1.82it/s]The following generation flags are not valid and may be ignored: ['temperature']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# LLM inference:  85%|████████▌ | 169/198 [01:59<00:14,  1.96it/s]The following generation flags are not valid and may be ignored: ['temperature']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# LLM inference:  86%|████████▌ | 170/198 [02:00<00:15,  1.80it/s]The following generation flags are not valid and may be ignored: ['temperature']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# LLM inference:  86%|████████▋ | 171/198 [02:00<00:15,  1.80it/s]The following generation flags are not valid and may be ignored: ['temperature']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# LLM inference:  87%|████████▋ | 172/198 [02:01<00:15,  1.70it/s]The following generation flags are not valid and may be ignored: ['temperature']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# LLM inference:  87%|████████▋ | 173/198 [02:02<00:13,  1.87it/s]The following generation flags are not valid and may be ignored: ['temperature']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# LLM inference:  88%|████████▊ | 174/198 [02:02<00:12,  1.87it/s]The following generation flags are not valid and may be ignored: ['temperature']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# LLM inference:  88%|████████▊ | 175/198 [02:03<00:12,  1.87it/s]The following generation flags are not valid and may be ignored: ['temperature']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# LLM inference:  89%|████████▉ | 176/198 [02:03<00:13,  1.64it/s]The following generation flags are not valid and may be ignored: ['temperature']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# LLM inference:  89%|████████▉ | 177/198 [02:04<00:12,  1.71it/s]The following generation flags are not valid and may be ignored: ['temperature']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# LLM inference:  90%|████████▉ | 178/198 [02:05<00:12,  1.64it/s]The following generation flags are not valid and may be ignored: ['temperature']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# LLM inference:  90%|█████████ | 179/198 [02:05<00:11,  1.61it/s]The following generation flags are not valid and may be ignored: ['temperature']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# LLM inference:  91%|█████████ | 180/198 [02:06<00:10,  1.66it/s]The following generation flags are not valid and may be ignored: ['temperature']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# LLM inference:  91%|█████████▏| 181/198 [02:06<00:10,  1.62it/s]The following generation flags are not valid and may be ignored: ['temperature']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# LLM inference:  92%|█████████▏| 182/198 [02:07<00:08,  1.79it/s]The following generation flags are not valid and may be ignored: ['temperature']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# LLM inference:  92%|█████████▏| 183/198 [02:07<00:08,  1.86it/s]The following generation flags are not valid and may be ignored: ['temperature']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# LLM inference:  93%|█████████▎| 184/198 [02:08<00:08,  1.69it/s]The following generation flags are not valid and may be ignored: ['temperature']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# LLM inference:  93%|█████████▎| 185/198 [02:09<00:07,  1.79it/s]The following generation flags are not valid and may be ignored: ['temperature']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# LLM inference:  94%|█████████▍| 186/198 [02:09<00:06,  1.80it/s]The following generation flags are not valid and may be ignored: ['temperature']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# LLM inference:  94%|█████████▍| 187/198 [02:10<00:06,  1.64it/s]The following generation flags are not valid and may be ignored: ['temperature']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# LLM inference:  95%|█████████▍| 188/198 [02:10<00:05,  1.88it/s]The following generation flags are not valid and may be ignored: ['temperature']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# LLM inference:  95%|█████████▌| 189/198 [02:11<00:04,  1.93it/s]The following generation flags are not valid and may be ignored: ['temperature']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# LLM inference:  96%|█████████▌| 190/198 [02:11<00:03,  2.05it/s]The following generation flags are not valid and may be ignored: ['temperature']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# LLM inference:  96%|█████████▋| 191/198 [02:12<00:03,  1.93it/s]The following generation flags are not valid and may be ignored: ['temperature']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# LLM inference:  97%|█████████▋| 192/198 [02:12<00:03,  1.97it/s]The following generation flags are not valid and may be ignored: ['temperature']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# LLM inference:  97%|█████████▋| 193/198 [02:13<00:02,  1.92it/s]The following generation flags are not valid and may be ignored: ['temperature']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# LLM inference:  98%|█████████▊| 194/198 [02:13<00:02,  1.88it/s]The following generation flags are not valid and may be ignored: ['temperature']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# LLM inference:  98%|█████████▊| 195/198 [02:14<00:01,  1.86it/s]The following generation flags are not valid and may be ignored: ['temperature']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# LLM inference:  99%|█████████▉| 196/198 [02:15<00:01,  1.68it/s]The following generation flags are not valid and may be ignored: ['temperature']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# LLM inference:  99%|█████████▉| 197/198 [02:15<00:00,  1.77it/s]The following generation flags are not valid and may be ignored: ['temperature']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# LLM inference: 100%|██████████| 198/198 [02:16<00:00,  1.45it/s]
# 샘플 수(유효): 198

# %% [markdown]
# ## 평가지표 계산 (Accuracy & MCC)

# %%
from sklearn.metrics import accuracy_score, matthews_corrcoef

acc = accuracy_score(golds, preds)
mcc = matthews_corrcoef(golds, preds)
print(f"Accuracy: {acc:.4f}")
print(f"Matthews Correlation Coefficient: {mcc:.4f}")
# Out:
# Accuracy: 0.5909
# Matthews Correlation Coefficient: 0.3017
